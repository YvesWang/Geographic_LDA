# %%
import json
from pprint import pprint

# %%
tweets=[]
for line in open('thirddebate.json', 'r'):
    tweets.append(json.loads(line))

# %%
tweets[7]['full_text']
# Out:
# 'RT @bfraser747: 💰💰 #ClintonCrimeFoundation\n\n#Pay2Play politics has to be stopped &amp; that obviously starts with #CrookedHillary\n\n#DrainTheSwa…'

# %%
tweets[7]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Wed Oct 19 11:17:34 +0000 2016',
#  'display_text_range': [0, 144],
#  'entities': {'hashtags': [{'indices': [19, 42],
#     'text': 'ClintonCrimeFoundation'},
#    {'indices': [44, 53], 'text': 'Pay2Play'},
#    {'indices': [114, 129], 'text': 'CrookedHillary'}],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 274891222,
#     'id_str': '274891222',
#     'indices': [3, 14],
#     'name': 'BRIAN FRASER',
#     'screen_name': 'bfraser747'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'full_text': 'RT @bfraser747: 💰💰 #ClintonCrimeFoundation\n\n#Pay2Play politics has to be stopped &amp; that obviously starts with #CrookedHillary\n\n#DrainTheSwa…',
#  'geo': None,
#  'id': 788700613844480000,
#  'id_str': '788700613844480001',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
# ...
